# %%
from ultralytics import YOLO

# %%
trained_model = YOLO(r"C:\Users\Asus\OneDrive\Desktop\target\ml\BrainTumor\runs\detect\train3\weights\best.pt")

# %%
results = trained_model(r'C:\Users\Asus\OneDrive\Desktop\target\ml\BrainTumor\brain-tumor\image.png')
# Out:
# image 1/1 C:\Users\Asus\OneDrive\Desktop\target\ml\BrainTumor\brain-tumor\image.png: 512x640 1 negative, 2 positives, 81.0ms
# Speed: 0.0ms preprocess, 81.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)

# %%
import matplotlib.pyplot as plt
from PIL import Image
# Ensure matplotlib inline mode
# %matplotlib inline
# Assuming results[0].plot() returns an array
image_array = results[0].plot()

# Display the image
plt.imshow(image_array)
plt.axis('off')  # Hide axes
plt.show()
